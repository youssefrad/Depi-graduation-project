# %% [markdown]
# # clean data for big data

# %%
! pip install openpyxl

# %%
import pandas as pd 
df=pd.read_excel('Online Retail.xlsx',engine='openpyxl')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.count()
# Out:
# InvoiceNo      541909
# StockCode      541909
# Description    540455
# Quantity       541909
# InvoiceDate    541909
# UnitPrice      541909
# CustomerID     406829
# Country        541909
# dtype: int64

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# # remove duplicate and misasing value

# %%
df_clean1 = df.dropna()

# %%
df_clean1 = df.drop_duplicates()

# %%
df_clean1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
# Convert 'custimer_id' column to int 
df_clean1['CustomerID']=df_clean1['CustomerID'].astype(int)
# Out:
# C:\Users\Abdo\AppData\Local\Temp\ipykernel_11176\4025128959.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean1['CustomerID']=df_clean1['CustomerID'].astype(int)

# %% [markdown]
# # some modification

# %%
df_clean1.rename(columns={'Country': 'branch_name', 'StockCode': 'product_name'}, inplace=True)
# Out:
# C:\Users\Abdo\AppData\Local\Temp\ipykernel_11176\1305638555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean1.rename(columns={'Country': 'branch_name', 'StockCode': 'product_name'}, inplace=True)

# %%
df_clean1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   InvoiceNo     406829 non-null  object
#  1   product_name  406829 non-null  object
#  2   Description   406829 non-null  object
#  3   Quantity      406829 non-null  int64
#  4   InvoiceDate   406829 non-null  datetime64[ns]
#  5   UnitPrice     406829 non-null  float64
#  6   CustomerID    406829 non-null  int64
#  7   branch_name   406829 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 27.9+ MB

# %%
df_clean1.head()
# Out:
#   InvoiceNo product_name                          Description  Quantity  \
# 0    536365       85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365        71053                  WHITE METAL LANTERN         6
# 2    536365       84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365       84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365       84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID     branch_name
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom

# %%
# Generate branch_id based on 'branch_name'

df_clean1['branch_id'] = df_clean1.groupby('branch_name').ngroup() + 1

# Generate product_id based on 'product_name'

df_clean1['product_id'] = df_clean1.groupby('product_name').ngroup() + 1
# Out:
# C:\Users\Abdo\AppData\Local\Temp\ipykernel_11176\574769195.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean1['branch_id'] = df_clean1.groupby('branch_name').ngroup() + 1
# C:\Users\Abdo\AppData\Local\Temp\ipykernel_11176\574769195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean1['product_id'] = df_clean1.groupby('product_name').ngroup() + 1

# %%
df_clean1['totalsales']= df_clean1['Quantity'] * df_clean1['UnitPrice']
df_clean1['quantity_sold']=df_clean1['Quantity']
# Out:
# C:\Users\Abdo\AppData\Local\Temp\ipykernel_11176\2138938247.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean1['totalsales']= df_clean1['Quantity'] * df_clean1['UnitPrice']
# C:\Users\Abdo\AppData\Local\Temp\ipykernel_11176\2138938247.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean1['quantity_sold']=df_clean1['Quantity']

# %%
# Dropping a single column
df_clean1.drop(columns='Quantity', inplace=True)
# Out:
# C:\Users\Abdo\AppData\Local\Temp\ipykernel_11176\2390903063.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean1.drop(columns='Quantity', inplace=True)

# %%
import numpy as np
df_clean1['salesperson_id'] = np.random.randint(1, 100, df_clean1.shape[0])
# Out:
# C:\Users\Abdo\AppData\Local\Temp\ipykernel_11176\1251572213.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean1['salesperson_id'] = np.random.randint(1, 100, df_clean1.shape[0])

# %%
df_clean1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   InvoiceNo       406829 non-null  object
#  1   product_name    406829 non-null  object
#  2   Description     406829 non-null  object
#  3   InvoiceDate     406829 non-null  datetime64[ns]
#  4   UnitPrice       406829 non-null  float64
#  5   CustomerID      406829 non-null  int64
#  6   branch_name     406829 non-null  object
#  7   branch_id       406829 non-null  int64
#  8   product_id      406829 non-null  int64
#  9   totalsales      406829 non-null  float64
#  10  quantity_sold   406829 non-null  int64
#  11  salesperson_id  406829 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(4), object(4)
# memory usage: 38.8+ MB

# %%
# Define the desired column order
desired_order = [
    'InvoiceNo',
    'InvoiceDate',
    'CustomerID',
    'branch_name',
    'branch_id',
    'salesperson_id',
    'product_id',
    'product_name',
    'Description',
    'quantity_sold',
    'UnitPrice',
    'totalsales'  
]
df_clean1=df_clean1[desired_order]
df_clean1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   InvoiceNo       406829 non-null  object
#  1   InvoiceDate     406829 non-null  datetime64[ns]
#  2   CustomerID      406829 non-null  int64
#  3   branch_name     406829 non-null  object
#  4   branch_id       406829 non-null  int64
#  5   salesperson_id  406829 non-null  int32
#  6   product_id      406829 non-null  int64
#  7   product_name    406829 non-null  object
#  8   Description     406829 non-null  object
#  9   quantity_sold   406829 non-null  int64
#  10  UnitPrice       406829 non-null  float64
#  11  totalsales      406829 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(4), object(4)
# memory usage: 38.8+ MB

# %%
df_clean1
# Out:
#        InvoiceNo         InvoiceDate  CustomerID     branch_name  branch_id  \
# 0         536365 2010-12-01 08:26:00       17850  United Kingdom         36
# 1         536365 2010-12-01 08:26:00       17850  United Kingdom         36
# 2         536365 2010-12-01 08:26:00       17850  United Kingdom         36
# 3         536365 2010-12-01 08:26:00       17850  United Kingdom         36
# 4         536365 2010-12-01 08:26:00       17850  United Kingdom         36
# ...          ...                 ...         ...             ...        ...
# 541904    581587 2011-12-09 12:50:00       12680          France         14
# 541905    581587 2011-12-09 12:50:00       12680          France         14
# 541906    581587 2011-12-09 12:50:00       12680          France         14
# 541907    581587 2011-12-09 12:50:00       12680          France         14
# 541908    581587 2011-12-09 12:50:00       12680          France         14
#
#         salesperson_id  product_id product_name  \
# ...

# %%
df_clean1['branch_name'] = df_clean1['branch_name'].replace('Israel', 'Egypt')

# %%
df_clean1['branch_name'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Egypt', 'Finland', 'Greece', 'Singapore', 'Lebanon',
#        'United Arab Emirates', 'Saudi Arabia', 'Czech Republic', 'Canada',
#        'Unspecified', 'Brazil', 'USA', 'European Community', 'Bahrain',
#        'Malta', 'RSA'], dtype=object)

# %%
df_clean1['InvoiceDate'] = pd.to_datetime(df_clean1['InvoiceDate'], unit='ms').dt.date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 df_clean1['InvoiceDate'] = pd.to_datetime(df_clean1['InvoiceDate'], unit='ms').dt.date
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# ...

# %%
df_clean1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   InvoiceNo       406829 non-null  object
#  1   InvoiceDate     406829 non-null  object
#  2   CustomerID      406829 non-null  int64
#  3   branch_name     406829 non-null  object
#  4   branch_id       406829 non-null  int64
#  5   salesperson_id  406829 non-null  int32
#  6   product_id      406829 non-null  int64
#  7   product_name    406829 non-null  object
#  8   Description     406829 non-null  object
#  9   quantity_sold   406829 non-null  int64
#  10  UnitPrice       406829 non-null  float64
#  11  totalsales      406829 non-null  float64
# dtypes: float64(2), int32(1), int64(4), object(5)
# memory usage: 54.9+ MB

# %%
df_clean1
# Out:
#        InvoiceNo InvoiceDate  CustomerID     branch_name  branch_id  \
# 0         536365  2010-12-01       17850  United Kingdom         36
# 1         536365  2010-12-01       17850  United Kingdom         36
# 2         536365  2010-12-01       17850  United Kingdom         36
# 3         536365  2010-12-01       17850  United Kingdom         36
# 4         536365  2010-12-01       17850  United Kingdom         36
# ...          ...         ...         ...             ...        ...
# 541904    581587  2011-12-09       12680          France         14
# 541905    581587  2011-12-09       12680          France         14
# 541906    581587  2011-12-09       12680          France         14
# 541907    581587  2011-12-09       12680          France         14
# 541908    581587  2011-12-09       12680          France         14
#
#         salesperson_id  product_id product_name  \
# 0                   57        3367       85123A
# 1                   74        2432        71053
# ...

# %% [markdown]
# # after finish load it into text file as  json

# %%
# Save DataFrame as a JSON file
df_clean1.to_json('bigdatafile', orient='records', lines=True)
